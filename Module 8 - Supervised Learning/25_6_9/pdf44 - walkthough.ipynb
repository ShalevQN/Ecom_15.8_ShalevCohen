# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import scipy

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ShalevQN/Ecom_15.8_ShalevCohen/refs/heads/main/Module%208%20-%20Supervised%20Learning/Advertising%20(3).csv')

df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df['total_spent'] = df['TV'] + df['radio'] + df['newspaper']

sns.scatterplot(data= df, x= 'total_spent', y= 'sales')
# Out:
# <Axes: xlabel='total_spent', ylabel='sales'>

# %%
sns.regplot(data= df, x= 'total_spent', y= 'sales')
# Out:
# <Axes: xlabel='total_spent', ylabel='sales'>

# %%
x = df['total_spent']
y = df['sales']

betas = np.polyfit(x, y, deg=1)
betas
# Out:
# array([0.04868788, 4.24302822])

# %%
expenses = 200
predicted_sales = expenses*betas[0] + betas[1] # Expenses * b1 + b0
predicted_sales
# Out:
# 13.980604079845957

# %%
potential_spends = np.linspace(0, 500, 100)
predicted_sales = betas[0] * potential_spends + betas[1]
plt.plot(potential_spends, predicted_sales)
plt.show()

# %%
sns.scatterplot(data= df, x= 'total_spent', y= 'sales')
plt.plot(potential_spends, predicted_sales, color= 'red')
plt.show()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ShalevQN/Ecom_15.8_ShalevCohen/refs/heads/main/Module%208%20-%20Supervised%20Learning/tips%20(4).csv')

df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
sns.scatterplot(data= df, x= 'total_bill', y= 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
betas = np.polyfit(df['total_bill'], df['tip'], deg= 1)
betas
# Out:
# array([0.10502452, 0.92026961])

# %%
sns.regplot(data= df, x= 'total_bill', y= 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
potential_bill = 150
predicted_tip = betas[0] * potential_bill + betas[1]
predicted_tip
# Out:
# 16.67394722120768

# %%
betas = np.polyfit(df['total_bill'], df['tip'], deg= 3)
betas
# Out:
# array([ 1.32767507e-04, -1.05394946e-02,  3.49076248e-01, -7.05888817e-01])
