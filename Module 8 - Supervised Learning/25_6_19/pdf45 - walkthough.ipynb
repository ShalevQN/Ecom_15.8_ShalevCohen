# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import scipy

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ShalevQN/Ecom_15.8_ShalevCohen/refs/heads/main/Module%208%20-%20Supervised%20Learning/Advertising%20(3).csv')

df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sns.pairplot(df, diag_kind= 'hist')

# %%
X = df.drop('sales', axis= 1)
y = df['sales']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state= 42)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
model.predict(X_test)
# Out:
# array([16.5653963 , 21.18822792, 21.55107058, 10.88923816, 22.20231988,
#        13.35556872, 21.19692502,  7.35028523, 13.27547079, 15.12449511,
#         9.01443026,  6.52542825, 14.30205991,  8.97026042,  9.45679576,
#        12.00454351,  8.91549403, 16.15619251, 10.29582883, 18.72473553,
#        19.76821818, 13.77469028, 12.49638908, 21.53501762,  7.60860741,
#         5.6119801 , 20.91759483, 11.80627665,  9.08076637,  8.51412012,
#        12.17604891,  9.9691939 , 21.73008956, 12.77770578, 18.1011362 ,
#        20.07590796, 14.26202556, 20.93826535, 10.83938827,  4.38190607,
#         9.51332406, 12.40486324, 10.17045434,  8.09081363, 13.16388427,
#         5.2243552 ,  9.28893833, 14.09330719,  8.69024497, 11.66119763,
#        15.71848432, 11.63156862, 13.35360735, 11.1531472 ,  6.33636845,
#         9.76157954,  9.4195714 , 24.25516546,  7.69519137, 12.15317572])

# %%
# Class Exerise
df = pd.read_csv('https://raw.githubusercontent.com/ShalevQN/Ecom_15.8_ShalevCohen/refs/heads/main/Module%208%20-%20Supervised%20Learning/Store_Sales_Data%20(1).csv')

df
# Out:
#     Number_of_Emloyees  Number_of_products  Area_of_Store  Store_Sales
# 0                  114                 164            266         7939
# 1                   98                  36             99         3462
# 2                  147                  34            105          454
# 3                   26                  67             71         5420
# 4                   53                 105            130         5554
# ..                 ...                 ...            ...          ...
# 95                 163                  61            135         2062
# 96                  95                  93             48         5912
# 97                  93                 112             13         8020
# 98                  20                  56             17         3452
# 99                  83                  22             66         1841
#
# [100 rows x 4 columns]

# %%
df.describe()
# Out:
#        Number_of_Emloyees  Number_of_products  Area_of_Store   Store_Sales
# count          100.000000          100.000000     100.000000    100.000000
# mean            89.520000           83.900000      87.980000   6011.240000
# std             57.664211           54.628497      66.425014   4197.926039
# min             14.000000           10.000000      10.000000     24.000000
# 25%             50.750000           44.000000      41.500000   3176.000000
# 50%             75.500000           71.500000      69.000000   5519.500000
# 75%            128.000000          105.250000     130.250000   7737.500000
# max            321.000000          261.000000     354.000000  19569.000000

# %%
sns.pairplot(df, diag_kind= 'hist') 
# Number of product x Sales
# both are correlated and dependent on each other.

# %%
X = df.drop('Store_Sales', axis= 1)
y = df['Store_Sales']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.15, random_state= 101)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
predictions
# Out:
# array([3151.3183261 , 2697.13061383, 4287.15841247, 5927.46975309,
#        2265.32186966, 6567.75301306, 7719.6151713 , 9620.65817742,
#        5044.47248691, 9844.2024234 ,  780.48795904, 3525.32929576,
#        2950.32261635, 9786.42408752, 3238.29240759])

# %%
X_test['predictions'] = predictions
X_test
# Out:
#     Number_of_Emloyees  Number_of_products  Area_of_Store  predictions
# 16                  18                  44             45  3151.318326
# 1                   98                  36             99  2697.130614
# 43                 180                  62             78  4287.158412
# 67                  82                  87             10  5927.469753
# 89                  82                  35             25  2265.321870
# 21                  89                  93             52  6567.753013
# 97                  93                 112             13  7719.615171
# 51                  69                 135             50  9620.658177
# 6                   15                  61            170  5044.472487
# 41                  87                 137             72  9844.202423
# 82                  73                  13             40   780.487959
# 25                  54                  43            143  3525.329296
# ...
